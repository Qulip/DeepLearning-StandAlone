# %%
from tensorflow.keras.layers import Dense, LeakyReLU, Dropout, Input, Reshape, GRU
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import RandomNormal
import numpy as np
import matplotlib.pyplot as plt
import os
import librosa
import pandas as pd
import librosa.display
import soundfile as sf
from tensorflow.keras.models import load_model   #jupyter  notebook
from google.colab import drive

drive.mount('/content/drive')
# %cd drive/MyDrive/Colab\ Notebooks

sr = 44100

# gan에 입력되는 noise에 대한 dimension
NOISE_DIM = 10 #잘 모르겠음...ㅎㅎ

# adam optimizer 정의, learning_rate = 0.0002, beta_1로 줍니다.
# Vanilla Gan과 DCGAN에서 이렇게 셋팅을 해주는데
# 이렇게 해줘야 훨씬 학습을 잘합니다.
# 그렇다고 합니다..ㅎㅎ
adam = Adam(lr=0.0002, beta_1=0.5)
mfcc_data = []
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/Colab Notebooks'
# /content/drive/MyDrive/Colab Notebooks
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
def load_wave_generator(path): #이전 깃헙에서 가져온 파일 읽어들이는 함수(라벨 붙이는것만 삭제)

    batch_waves = []
    X_data = []
    temp = []
    global mfcc_data

    folders = os.listdir(path)

    for folder in folders:
        if not os.path.isdir(path):continue #폴더가 아니면 continue
        files = os.listdir(path+"/"+folder)
        print("Foldername :",folder,"-",len(files),"files")
        #폴더 이름과 그 폴더에 속하는 파일 갯수 출력
        for wav in files:
            if not wav.endswith(".wav"):continue
            else:
                print("Filename :",wav)#.wav 파일이 아니면 continue
                y, sr = librosa.load(path+"/"+folder+"/"+wav)
                mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=45, hop_length=int(sr*0.01),n_fft=int(sr*0.02)).T

                X_data.extend(mfcc)
                #print("MFCC Size : ", len(mfcc))
    #end loop
    print("X_data :",np.shape(X_data))
    mfcc_data = X_data
    

load_wave_generator("./data")    #일단 RYU 음성 읽어오기
print(np.shape(mfcc_data))
# Out:
# Foldername : 1 - 20 files
# Filename : Ryu17.wav
# Filename : Ryu20.wav
# Filename : Ryu18.wav
# Filename : Ryu3.wav
# Filename : Ryu13.wav
# Filename : Ryu4.wav
# Filename : Ryu8.wav
# Filename : Ryu1.wav
# Filename : Ryu5.wav
# Filename : Ryu9.wav
# Filename : Ryu2.wav
# Filename : Ryu6.wav
# Filename : Ryu11.wav
# Filename : Ryu10.wav
# Filename : Ryu12.wav
# Filename : Ryu14.wav
# Filename : Ryu19.wav
# Filename : Ryu7.wav
# Filename : Ryu15.wav
# Filename : Ryu16.wav
# X_data : (15505, 45)
# (15505, 45)

# %%
def make_data(data):
    a = []
    data = np.random.permutation(data)
    
    for j, row in enumerate(data):
        if(j+500 == len(data)):
            a = np.array(a)
            return a
        a.append(data[j:j+500])

X_train = make_data(mfcc_data)
X_train.shape
# Out:
# (15005, 500, 45)

# %%
generator = Sequential([                 #generator 모델 생성  
    Dense(256, input_dim=NOISE_DIM), 
    LeakyReLU(0.2), 
    Dense(512), 
    LeakyReLU(0.2), 
    Dense(1024), 
    LeakyReLU(0.2), 
    Dense(22500, activation='tanh'),
    Reshape((500,45), input_shape=(22500,)),
])

# %%
generator.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 256)               2816
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 22500)             23062500
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 500, 45)           0
# =================================================================
# Total params: 23,722,212
# Trainable params: 23,722,212
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator = Sequential()
discriminator.add(GRU(128, input_shape=(500,45)))
discriminator.add(Dense(64, activation='relu'))
discriminator.add(Dense(32, activation='relu'))
discriminator.add(Dense(1, activation='sigmoid'))

discriminator.compile(loss='binary_crossentropy', optimizer=adam)

# %%
discriminator.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 128)               67200
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 77,569
# Trainable params: 77,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator.compile(loss='binary_crossentropy', optimizer=adam)

# %%
discriminator.trainable = False
gan_input = Input(shape=(NOISE_DIM,))
x = generator(inputs=gan_input)
output = discriminator(x)
gan = Model(gan_input, output)

# %%
gan.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 10)]              0
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 500, 45)           23722212
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 1)                 77569
# =================================================================
# Total params: 23,799,781
# Trainable params: 23,722,212
# Non-trainable params: 77,569
# _________________________________________________________________

# %%
gan.compile(loss='binary_crossentropy', optimizer=adam)

# %%
model = load_model('gru_4-26(100%).h5', compile = False)

def test_voice(X_s, model):
    test = X_s

    y_pred = np.argmax(model.predict(test), axis=-1)
    return who(y_pred)

def who(y_pred):
  aaa = 0
  bbb = 0
  ccc = 0
  for i in range(0, len(y_pred)):
    if(y_pred[i] == 0):
      aaa = aaa + 1
    elif(y_pred[i] == 1):
      bbb = bbb + 1
    else:
      ccc = ccc + 1

  result = [aaa,bbb,ccc]
  return result.index(max(result)), result

def model_predict_return(X_s, model):
  # files = os.listdir(path)
    result_index, result = test_voice(X_s, model)

    if result_index == 0:
      return "최창준 목소리 입니다"
    elif result_index == 1:
      return "유일권 목소리 입니다"
    else:
      return "경재원 목소리 입니다"

def chk_predict(generated, epoch):
    gen_mfcc = []
    for i in range(len(generated)):
        for j in range(5):
            gen_mfcc.append(generated[i][j*100:j*100+100])

    gen_mfcc = np.array(gen_mfcc)
    print("Epoch : ",epoch," ", model_predict_return(gen_mfcc, model))

# %%
def visualize_training(epoch, d_losses, g_losses, generated):
    # 오차에 대한 시각화
    plt.figure(figsize=(8, 4))
    plt.plot(d_losses, label='Discriminator Loss')
    plt.plot(g_losses, label='Generatror Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    print('epoch: {}, Discriminator Loss: {}, Generator Loss: {}'.format(epoch, np.asarray(d_losses).mean(), np.asarray(g_losses).mean()))
    
    #test = librosa.feature.inverse.mfcc_to_audio(generated[31].T)
    #librosa.display.waveplot(test, sr=sr, color='r')

# %%
def get_batches(data, batch_size):
    batches = []
    for i in range(int(len(data) // batch_size)):
        batch = data[i * batch_size: (i + 1) * batch_size]
        batches.append(batch)
    return np.asarray(batches)

# %%
BATCH_SIZE = 32
EPOCHS = 50

# %%
d_losses = []   # discriminator와 gan 모델의 loss 측정을 위한 list 입니다.
g_losses = []
gen_rst = []

for epoch in range(1, EPOCHS + 1):
    for real_sounds in get_batches(X_train, BATCH_SIZE):
        input_noise = np.random.uniform(-1, 1, size=[BATCH_SIZE, NOISE_DIM])    # 랜덤 노이즈 생성
        
        generated_sounds = generator.predict(input_noise)                       # 가짜 데이터 생성

        x_dis = np.concatenate([real_sounds, generated_sounds])                 # Gan에 학습할 X 데이터 정의
        
        y_dis = np.zeros(2 * BATCH_SIZE)                                        # Gan에 학습할 Y 데이터 정의
        y_dis[:BATCH_SIZE] = 0.9
        
        discriminator.trainable = True
        d_loss = discriminator.train_on_batch(x_dis, y_dis)                     # Discriminator 훈련
        
        noise = np.random.uniform(-1, 1, size=[BATCH_SIZE, NOISE_DIM])          # Gan 훈련
        y_gan = np.ones(BATCH_SIZE)
        
        discriminator.trainable = False                                         # Discriminator의 판별 학습을 방지합니다
        g_loss = gan.train_on_batch(noise, y_gan)
        
    d_losses.append(d_loss)
    g_losses.append(g_loss)
    
    chk_predict(generated_sounds, epoch)                                        #가짜 음성데이터에 대한 화자 인식

    if(epoch==EPOCHS):                                                          #학습 종료시 마지막 음성데이터 확인 및 학습 확인
        gen_rst=np.array(generated_sounds)
        visualize_training(epoch, d_losses, g_losses, generated_sounds)
# Out:
# Epoch :  1   최창준 목소리 입니다
# Epoch :  2   최창준 목소리 입니다
# Epoch :  3   유일권 목소리 입니다
# Epoch :  4   최창준 목소리 입니다
# Epoch :  5   최창준 목소리 입니다
# Epoch :  6   최창준 목소리 입니다
# Epoch :  7   최창준 목소리 입니다
# Epoch :  8   최창준 목소리 입니다
# Epoch :  9   최창준 목소리 입니다
# Epoch :  10   최창준 목소리 입니다
# Epoch :  11   최창준 목소리 입니다
# Epoch :  12   최창준 목소리 입니다
# Epoch :  13   최창준 목소리 입니다
# Epoch :  14   최창준 목소리 입니다
# Epoch :  15   유일권 목소리 입니다
# Epoch :  16   유일권 목소리 입니다
# Epoch :  17   유일권 목소리 입니다
# Epoch :  18   유일권 목소리 입니다
# Epoch :  19   유일권 목소리 입니다
# Epoch :  20   유일권 목소리 입니다
# Epoch :  21   유일권 목소리 입니다
# Epoch :  22   유일권 목소리 입니다
# Epoch :  23   유일권 목소리 입니다
# Epoch :  24   유일권 목소리 입니다
# Epoch :  25   유일권 목소리 입니다
# Epoch :  26   유일권 목소리 입니다
# Epoch :  27   유일권 목소리 입니다
# Epoch :  28   유일권 목소리 입니다
# Epoch :  29   유일권 목소리 입니다
# Epoch :  30   유일권 목소리 입니다
# Epoch :  31   유일권 목소리 입니다
# Epoch :  32   유일권 목소리 입니다
# Epoch :  33   유일권 목소리 입니다
# Epoch :  34   유일권 목소리 입니다
# Epoch :  35   유일권 목소리 입니다
# Epoch :  36   유일권 목소리 입니다
# Epoch :  37   유일권 목소리 입니다
# Epoch :  38   유일권 목소리 입니다
# Epoch :  39   유일권 목소리 입니다
# Epoch :  40   유일권 목소리 입니다
# Epoch :  41   유일권 목소리 입니다
# Epoch :  42   유일권 목소리 입니다
# Epoch :  43   유일권 목소리 입니다
# Epoch :  44   유일권 목소리 입니다
# Epoch :  45   유일권 목소리 입니다
# Epoch :  46   유일권 목소리 입니다
# Epoch :  47   유일권 목소리 입니다
# Epoch :  48   유일권 목소리 입니다
# Epoch :  49   유일권 목소리 입니다
# Epoch :  50   유일권 목소리 입니다
# epoch: 50, Discriminator Loss: 0.16255318790674209, Generator Loss: 18.248336067199705

# %%
per = [0,0,0];

def chk_GAN_rst(generated, model, epoch):
    gen_mfcc = []
    for i in range(len(generated)):
        for j in range(5):
            gen_mfcc.append(generated[i][j*100:j*100+100])

    gen_mfcc = np.array(gen_mfcc)

    result_index, result = test_voice(gen_mfcc, model)
    per[result_index] = per[result_index]+1

    if result_index == 0:
      rst =  "최창준 목소리 입니다"
    elif result_index == 1:
      rst =  "유일권 목소리 입니다"
    else:
      rst = "경재원 목소리 입니다"
    print("Epoch : ",epoch," ", rst)

for i in range(1000):
    input_noise = np.random.uniform(-1, 1, size=[1,10])
    generated_sounds = generator.predict(input_noise)
    chk_GAN_rst(generated_sounds, model, i)

per
# Out:
# Epoch :  0   유일권 목소리 입니다
# Epoch :  1   유일권 목소리 입니다
# Epoch :  2   유일권 목소리 입니다
# Epoch :  3   유일권 목소리 입니다
# Epoch :  4   유일권 목소리 입니다
# Epoch :  5   유일권 목소리 입니다
# Epoch :  6   유일권 목소리 입니다
# Epoch :  7   유일권 목소리 입니다
# Epoch :  8   유일권 목소리 입니다
# Epoch :  9   유일권 목소리 입니다
# Epoch :  10   유일권 목소리 입니다
# Epoch :  11   유일권 목소리 입니다
# Epoch :  12   유일권 목소리 입니다
# Epoch :  13   유일권 목소리 입니다
# Epoch :  14   유일권 목소리 입니다
# Epoch :  15   유일권 목소리 입니다
# Epoch :  16   유일권 목소리 입니다
# Epoch :  17   유일권 목소리 입니다
# Epoch :  18   유일권 목소리 입니다
# Epoch :  19   유일권 목소리 입니다
# Epoch :  20   유일권 목소리 입니다
# Epoch :  21   유일권 목소리 입니다
# Epoch :  22   유일권 목소리 입니다
# Epoch :  23   유일권 목소리 입니다
# Epoch :  24   유일권 목소리 입니다
# Epoch :  25   유일권 목소리 입니다
# Epoch :  26   유일권 목소리 입니다
# Epoch :  27   유일권 목소리 입니다
# Epoch :  28   유일권 목소리 입니다
# Epoch :  29   유일권 목소리 입니다
# Epoch :  30   유일권 목소리 입니다
# Epoch :  31   유일권 목소리 입니다
# Epoch :  32   유일권 목소리 입니다
# Epoch :  33   유일권 목소리 입니다
# Epoch :  34   유일권 목소리 입니다
# Epoch :  35   유일권 목소리 입니다
# Epoch :  36   유일권 목소리 입니다
# Epoch :  37   유일권 목소리 입니다
# Epoch :  38   유일권 목소리 입니다
# Epoch :  39   유일권 목소리 입니다
# Epoch :  40   유일권 목소리 입니다
# Epoch :  41   유일권 목소리 입니다
# Epoch :  42   유일권 목소리 입니다
# Epoch :  43   유일권 목소리 입니다
# Epoch :  44   유일권 목소리 입니다
# Epoch :  45   유일권 목소리 입니다
# Epoch :  46   유일권 목소리 입니다
# Epoch :  47   유일권 목소리 입니다
# Epoch :  48   유일권 목소리 입니다
# Epoch :  49   유일권 목소리 입니다
# Epoch :  50   유일권 목소리 입니다
# Epoch :  51   유일권 목소리 입니다
# Epoch :  52   유일권 목소리 입니다
# Epoch :  53   유일권 목소리 입니다
# Epoch :  54   유일권 목소리 입니다
# Epoch :  55   유일권 목소리 입니다
# Epoch :  56   유일권 목소리 입니다
# Epoch :  57   유일권 목소리 입니다
# Epoch :  58   유일권 목소리 입니다
# Epoch :  59   유일권 목소리 입니다
# Epoch :  60   유일권 목소리 입니다
# Epoch :  61   유일권 목소리 입니다
# Epoch :  62   유일권 목소리 입니다
# Epoch :  63   유일권 목소리 입니다
# Epoch :  64   유일권 목소리 입니다
# Epoch :  65   유일권 목소리 입니다
# Epoch :  66   유일권 목소리 입니다
# Epoch :  67   유일권 목소리 입니다
# Epoch :  68   유일권 목소리 입니다
# Epoch :  69   유일권 목소리 입니다
# Epoch :  70   유일권 목소리 입니다
# Epoch :  71   유일권 목소리 입니다
# Epoch :  72   유일권 목소리 입니다
# Epoch :  73   유일권 목소리 입니다
# Epoch :  74   유일권 목소리 입니다
# Epoch :  75   유일권 목소리 입니다
# Epoch :  76   유일권 목소리 입니다
# Epoch :  77   유일권 목소리 입니다
# Epoch :  78   유일권 목소리 입니다
# Epoch :  79   유일권 목소리 입니다
# Epoch :  80   유일권 목소리 입니다
# Epoch :  81   유일권 목소리 입니다
# Epoch :  82   유일권 목소리 입니다
# Epoch :  83   유일권 목소리 입니다
# Epoch :  84   유일권 목소리 입니다
# Epoch :  85   유일권 목소리 입니다
# Epoch :  86   유일권 목소리 입니다
# Epoch :  87   유일권 목소리 입니다
# Epoch :  88   유일권 목소리 입니다
# Epoch :  89   유일권 목소리 입니다
# Epoch :  90   유일권 목소리 입니다
# Epoch :  91   유일권 목소리 입니다
# Epoch :  92   유일권 목소리 입니다
# Epoch :  93   유일권 목소리 입니다
# Epoch :  94   유일권 목소리 입니다
# Epoch :  95   유일권 목소리 입니다
# Epoch :  96   유일권 목소리 입니다
# Epoch :  97   유일권 목소리 입니다
# Epoch :  98   유일권 목소리 입니다
# Epoch :  99   유일권 목소리 입니다
# Epoch :  100   유일권 목소리 입니다
# Epoch :  101   유일권 목소리 입니다
# Epoch :  102   유일권 목소리 입니다
# Epoch :  103   유일권 목소리 입니다
# Epoch :  104   유일권 목소리 입니다
# Epoch :  105   유일권 목소리 입니다
# Epoch :  106   유일권 목소리 입니다
# Epoch :  107   유일권 목소리 입니다
# Epoch :  108   유일권 목소리 입니다
# Epoch :  109   유일권 목소리 입니다
# Epoch :  110   유일권 목소리 입니다
# Epoch :  111   유일권 목소리 입니다
# Epoch :  112   유일권 목소리 입니다
# Epoch :  113   유일권 목소리 입니다
# Epoch :  114   유일권 목소리 입니다
# Epoch :  115   유일권 목소리 입니다
# Epoch :  116   유일권 목소리 입니다
# Epoch :  117   유일권 목소리 입니다
# Epoch :  118   유일권 목소리 입니다
# Epoch :  119   유일권 목소리 입니다
# Epoch :  120   유일권 목소리 입니다
# Epoch :  121   유일권 목소리 입니다
# Epoch :  122   유일권 목소리 입니다
# Epoch :  123   유일권 목소리 입니다
# Epoch :  124   유일권 목소리 입니다
# Epoch :  125   유일권 목소리 입니다
# Epoch :  126   유일권 목소리 입니다
# Epoch :  127   유일권 목소리 입니다
# Epoch :  128   유일권 목소리 입니다
# Epoch :  129   유일권 목소리 입니다
# Epoch :  130   유일권 목소리 입니다
# Epoch :  131   유일권 목소리 입니다
# Epoch :  132   유일권 목소리 입니다
# Epoch :  133   유일권 목소리 입니다
# Epoch :  134   유일권 목소리 입니다
# Epoch :  135   유일권 목소리 입니다
# Epoch :  136   유일권 목소리 입니다
# Epoch :  137   유일권 목소리 입니다
# Epoch :  138   유일권 목소리 입니다
# Epoch :  139   유일권 목소리 입니다
# Epoch :  140   유일권 목소리 입니다
# Epoch :  141   유일권 목소리 입니다
# Epoch :  142   유일권 목소리 입니다
# Epoch :  143   유일권 목소리 입니다
# Epoch :  144   유일권 목소리 입니다
# Epoch :  145   유일권 목소리 입니다
# Epoch :  146   유일권 목소리 입니다
# Epoch :  147   유일권 목소리 입니다
# Epoch :  148   유일권 목소리 입니다
# Epoch :  149   유일권 목소리 입니다
# Epoch :  150   유일권 목소리 입니다
# Epoch :  151   유일권 목소리 입니다
# Epoch :  152   유일권 목소리 입니다
# Epoch :  153   유일권 목소리 입니다
# Epoch :  154   유일권 목소리 입니다
# Epoch :  155   유일권 목소리 입니다
# Epoch :  156   유일권 목소리 입니다
# Epoch :  157   유일권 목소리 입니다
# Epoch :  158   유일권 목소리 입니다
# Epoch :  159   유일권 목소리 입니다
# Epoch :  160   유일권 목소리 입니다
# Epoch :  161   유일권 목소리 입니다
# Epoch :  162   유일권 목소리 입니다
# Epoch :  163   유일권 목소리 입니다
# Epoch :  164   유일권 목소리 입니다
# Epoch :  165   유일권 목소리 입니다
# Epoch :  166   유일권 목소리 입니다
# Epoch :  167   유일권 목소리 입니다
# Epoch :  168   유일권 목소리 입니다
# Epoch :  169   유일권 목소리 입니다
# Epoch :  170   유일권 목소리 입니다
# Epoch :  171   유일권 목소리 입니다
# Epoch :  172   유일권 목소리 입니다
# Epoch :  173   유일권 목소리 입니다
# Epoch :  174   유일권 목소리 입니다
# Epoch :  175   유일권 목소리 입니다
# Epoch :  176   유일권 목소리 입니다
# Epoch :  177   유일권 목소리 입니다
# Epoch :  178   유일권 목소리 입니다
# Epoch :  179   유일권 목소리 입니다
# Epoch :  180   유일권 목소리 입니다
# Epoch :  181   유일권 목소리 입니다
# Epoch :  182   유일권 목소리 입니다
# Epoch :  183   유일권 목소리 입니다
# Epoch :  184   유일권 목소리 입니다
# Epoch :  185   유일권 목소리 입니다
# Epoch :  186   유일권 목소리 입니다
# Epoch :  187   유일권 목소리 입니다
# Epoch :  188   유일권 목소리 입니다
# Epoch :  189   유일권 목소리 입니다
# Epoch :  190   유일권 목소리 입니다
# Epoch :  191   유일권 목소리 입니다
# Epoch :  192   유일권 목소리 입니다
# Epoch :  193   유일권 목소리 입니다
# Epoch :  194   유일권 목소리 입니다
# Epoch :  195   유일권 목소리 입니다
# Epoch :  196   유일권 목소리 입니다
# Epoch :  197   유일권 목소리 입니다
# Epoch :  198   유일권 목소리 입니다
# Epoch :  199   유일권 목소리 입니다
# Epoch :  200   유일권 목소리 입니다
# Epoch :  201   유일권 목소리 입니다
# Epoch :  202   유일권 목소리 입니다
# Epoch :  203   유일권 목소리 입니다
# Epoch :  204   유일권 목소리 입니다
# Epoch :  205   유일권 목소리 입니다
# Epoch :  206   유일권 목소리 입니다
# Epoch :  207   유일권 목소리 입니다
# Epoch :  208   유일권 목소리 입니다
# Epoch :  209   유일권 목소리 입니다
# Epoch :  210   유일권 목소리 입니다
# Epoch :  211   유일권 목소리 입니다
# Epoch :  212   유일권 목소리 입니다
# Epoch :  213   유일권 목소리 입니다
# Epoch :  214   유일권 목소리 입니다
# Epoch :  215   유일권 목소리 입니다
# Epoch :  216   유일권 목소리 입니다
# Epoch :  217   유일권 목소리 입니다
# Epoch :  218   유일권 목소리 입니다
# Epoch :  219   유일권 목소리 입니다
# Epoch :  220   유일권 목소리 입니다
# Epoch :  221   유일권 목소리 입니다
# Epoch :  222   유일권 목소리 입니다
# Epoch :  223   유일권 목소리 입니다
# Epoch :  224   경재원 목소리 입니다
# Epoch :  225   유일권 목소리 입니다
# Epoch :  226   유일권 목소리 입니다
# Epoch :  227   유일권 목소리 입니다
# Epoch :  228   유일권 목소리 입니다
# Epoch :  229   유일권 목소리 입니다
# Epoch :  230   유일권 목소리 입니다
# Epoch :  231   유일권 목소리 입니다
# Epoch :  232   유일권 목소리 입니다
# Epoch :  233   유일권 목소리 입니다
# Epoch :  234   유일권 목소리 입니다
# Epoch :  235   유일권 목소리 입니다
# Epoch :  236   유일권 목소리 입니다
# Epoch :  237   유일권 목소리 입니다
# Epoch :  238   유일권 목소리 입니다
# Epoch :  239   유일권 목소리 입니다
# Epoch :  240   유일권 목소리 입니다
# Epoch :  241   유일권 목소리 입니다
# Epoch :  242   유일권 목소리 입니다
# Epoch :  243   유일권 목소리 입니다
# Epoch :  244   유일권 목소리 입니다
# Epoch :  245   유일권 목소리 입니다
# Epoch :  246   유일권 목소리 입니다
# Epoch :  247   유일권 목소리 입니다
# Epoch :  248   유일권 목소리 입니다
# Epoch :  249   유일권 목소리 입니다
# Epoch :  250   유일권 목소리 입니다
# Epoch :  251   유일권 목소리 입니다
# Epoch :  252   유일권 목소리 입니다
# Epoch :  253   유일권 목소리 입니다
# Epoch :  254   유일권 목소리 입니다
# Epoch :  255   유일권 목소리 입니다
# Epoch :  256   유일권 목소리 입니다
# Epoch :  257   유일권 목소리 입니다
# Epoch :  258   유일권 목소리 입니다
# Epoch :  259   유일권 목소리 입니다
# Epoch :  260   유일권 목소리 입니다
# Epoch :  261   유일권 목소리 입니다
# Epoch :  262   유일권 목소리 입니다
# Epoch :  263   유일권 목소리 입니다
# Epoch :  264   유일권 목소리 입니다
# Epoch :  265   유일권 목소리 입니다
# Epoch :  266   유일권 목소리 입니다
# Epoch :  267   유일권 목소리 입니다
# Epoch :  268   유일권 목소리 입니다
# Epoch :  269   유일권 목소리 입니다
# Epoch :  270   유일권 목소리 입니다
# Epoch :  271   유일권 목소리 입니다
# Epoch :  272   유일권 목소리 입니다
# Epoch :  273   유일권 목소리 입니다
# Epoch :  274   유일권 목소리 입니다
# Epoch :  275   유일권 목소리 입니다
# Epoch :  276   유일권 목소리 입니다
# Epoch :  277   유일권 목소리 입니다
# Epoch :  278   유일권 목소리 입니다
# Epoch :  279   유일권 목소리 입니다
# Epoch :  280   유일권 목소리 입니다
# Epoch :  281   유일권 목소리 입니다
# Epoch :  282   유일권 목소리 입니다
# Epoch :  283   유일권 목소리 입니다
# Epoch :  284   유일권 목소리 입니다
# Epoch :  285   유일권 목소리 입니다
# Epoch :  286   유일권 목소리 입니다
# Epoch :  287   유일권 목소리 입니다
# Epoch :  288   유일권 목소리 입니다
# Epoch :  289   유일권 목소리 입니다
# Epoch :  290   유일권 목소리 입니다
# Epoch :  291   유일권 목소리 입니다
# Epoch :  292   경재원 목소리 입니다
# Epoch :  293   유일권 목소리 입니다
# Epoch :  294   유일권 목소리 입니다
# Epoch :  295   유일권 목소리 입니다
# Epoch :  296   유일권 목소리 입니다
# Epoch :  297   유일권 목소리 입니다
# Epoch :  298   유일권 목소리 입니다
# Epoch :  299   유일권 목소리 입니다
# Epoch :  300   유일권 목소리 입니다
# Epoch :  301   유일권 목소리 입니다
# Epoch :  302   유일권 목소리 입니다
# Epoch :  303   유일권 목소리 입니다
# Epoch :  304   유일권 목소리 입니다
# Epoch :  305   유일권 목소리 입니다
# Epoch :  306   유일권 목소리 입니다
# Epoch :  307   유일권 목소리 입니다
# Epoch :  308   유일권 목소리 입니다
# Epoch :  309   유일권 목소리 입니다
# Epoch :  310   유일권 목소리 입니다
# Epoch :  311   유일권 목소리 입니다
# Epoch :  312   유일권 목소리 입니다
# Epoch :  313   유일권 목소리 입니다
# Epoch :  314   유일권 목소리 입니다
# Epoch :  315   유일권 목소리 입니다
# Epoch :  316   유일권 목소리 입니다
# Epoch :  317   유일권 목소리 입니다
# Epoch :  318   유일권 목소리 입니다
# Epoch :  319   유일권 목소리 입니다
# Epoch :  320   유일권 목소리 입니다
# Epoch :  321   유일권 목소리 입니다
# Epoch :  322   유일권 목소리 입니다
# Epoch :  323   유일권 목소리 입니다
# Epoch :  324   유일권 목소리 입니다
# Epoch :  325   유일권 목소리 입니다
# Epoch :  326   유일권 목소리 입니다
# Epoch :  327   유일권 목소리 입니다
# Epoch :  328   유일권 목소리 입니다
# Epoch :  329   유일권 목소리 입니다
# Epoch :  330   유일권 목소리 입니다
# Epoch :  331   유일권 목소리 입니다
# Epoch :  332   유일권 목소리 입니다
# Epoch :  333   유일권 목소리 입니다
# Epoch :  334   유일권 목소리 입니다
# Epoch :  335   유일권 목소리 입니다
# Epoch :  336   유일권 목소리 입니다
# Epoch :  337   유일권 목소리 입니다
# Epoch :  338   유일권 목소리 입니다
# Epoch :  339   유일권 목소리 입니다
# Epoch :  340   유일권 목소리 입니다
# Epoch :  341   유일권 목소리 입니다
# Epoch :  342   유일권 목소리 입니다
# Epoch :  343   유일권 목소리 입니다
# Epoch :  344   유일권 목소리 입니다
# Epoch :  345   유일권 목소리 입니다
# Epoch :  346   유일권 목소리 입니다
# Epoch :  347   유일권 목소리 입니다
# Epoch :  348   유일권 목소리 입니다
# Epoch :  349   유일권 목소리 입니다
# Epoch :  350   유일권 목소리 입니다
# Epoch :  351   유일권 목소리 입니다
# Epoch :  352   유일권 목소리 입니다
# Epoch :  353   유일권 목소리 입니다
# Epoch :  354   유일권 목소리 입니다
# Epoch :  355   유일권 목소리 입니다
# Epoch :  356   유일권 목소리 입니다
# Epoch :  357   유일권 목소리 입니다
# Epoch :  358   유일권 목소리 입니다
# Epoch :  359   유일권 목소리 입니다
# Epoch :  360   유일권 목소리 입니다
# Epoch :  361   유일권 목소리 입니다
# Epoch :  362   유일권 목소리 입니다
# Epoch :  363   유일권 목소리 입니다
# Epoch :  364   유일권 목소리 입니다
# Epoch :  365   유일권 목소리 입니다
# Epoch :  366   유일권 목소리 입니다
# Epoch :  367   유일권 목소리 입니다
# Epoch :  368   유일권 목소리 입니다
# Epoch :  369   유일권 목소리 입니다
# Epoch :  370   유일권 목소리 입니다
# Epoch :  371   유일권 목소리 입니다
# Epoch :  372   유일권 목소리 입니다
# Epoch :  373   유일권 목소리 입니다
# Epoch :  374   유일권 목소리 입니다
# Epoch :  375   유일권 목소리 입니다
# Epoch :  376   유일권 목소리 입니다
# Epoch :  377   유일권 목소리 입니다
# Epoch :  378   유일권 목소리 입니다
# Epoch :  379   유일권 목소리 입니다
# Epoch :  380   유일권 목소리 입니다
# Epoch :  381   유일권 목소리 입니다
# Epoch :  382   경재원 목소리 입니다
# Epoch :  383   유일권 목소리 입니다
# Epoch :  384   유일권 목소리 입니다
# Epoch :  385   유일권 목소리 입니다
# Epoch :  386   유일권 목소리 입니다
# Epoch :  387   유일권 목소리 입니다
# Epoch :  388   유일권 목소리 입니다
# Epoch :  389   유일권 목소리 입니다
# Epoch :  390   유일권 목소리 입니다
# Epoch :  391   유일권 목소리 입니다
# Epoch :  392   유일권 목소리 입니다
# Epoch :  393   유일권 목소리 입니다
# Epoch :  394   유일권 목소리 입니다
# Epoch :  395   유일권 목소리 입니다
# Epoch :  396   유일권 목소리 입니다
# Epoch :  397   유일권 목소리 입니다
# Epoch :  398   유일권 목소리 입니다
# Epoch :  399   유일권 목소리 입니다
# Epoch :  400   유일권 목소리 입니다
# Epoch :  401   유일권 목소리 입니다
# Epoch :  402   유일권 목소리 입니다
# Epoch :  403   유일권 목소리 입니다
# Epoch :  404   유일권 목소리 입니다
# Epoch :  405   유일권 목소리 입니다
# Epoch :  406   유일권 목소리 입니다
# Epoch :  407   유일권 목소리 입니다
# Epoch :  408   유일권 목소리 입니다
# Epoch :  409   유일권 목소리 입니다
# Epoch :  410   유일권 목소리 입니다
# Epoch :  411   유일권 목소리 입니다
# Epoch :  412   유일권 목소리 입니다
# Epoch :  413   유일권 목소리 입니다
# Epoch :  414   유일권 목소리 입니다
# Epoch :  415   유일권 목소리 입니다
# Epoch :  416   유일권 목소리 입니다
# Epoch :  417   유일권 목소리 입니다
# Epoch :  418   유일권 목소리 입니다
# Epoch :  419   유일권 목소리 입니다
# Epoch :  420   유일권 목소리 입니다
# Epoch :  421   유일권 목소리 입니다
# Epoch :  422   유일권 목소리 입니다
# Epoch :  423   유일권 목소리 입니다
# Epoch :  424   유일권 목소리 입니다
# Epoch :  425   유일권 목소리 입니다
# Epoch :  426   유일권 목소리 입니다
# Epoch :  427   유일권 목소리 입니다
# Epoch :  428   유일권 목소리 입니다
# Epoch :  429   유일권 목소리 입니다
# Epoch :  430   유일권 목소리 입니다
# Epoch :  431   유일권 목소리 입니다
# Epoch :  432   유일권 목소리 입니다
# Epoch :  433   유일권 목소리 입니다
# Epoch :  434   유일권 목소리 입니다
# Epoch :  435   유일권 목소리 입니다
# Epoch :  436   유일권 목소리 입니다
# Epoch :  437   유일권 목소리 입니다
# Epoch :  438   유일권 목소리 입니다
# Epoch :  439   유일권 목소리 입니다
# Epoch :  440   유일권 목소리 입니다
# Epoch :  441   유일권 목소리 입니다
# Epoch :  442   유일권 목소리 입니다
# Epoch :  443   유일권 목소리 입니다
# Epoch :  444   유일권 목소리 입니다
# Epoch :  445   유일권 목소리 입니다
# Epoch :  446   유일권 목소리 입니다
# Epoch :  447   유일권 목소리 입니다
# Epoch :  448   유일권 목소리 입니다
# Epoch :  449   유일권 목소리 입니다
# Epoch :  450   유일권 목소리 입니다
# Epoch :  451   유일권 목소리 입니다
# Epoch :  452   유일권 목소리 입니다
# Epoch :  453   유일권 목소리 입니다
# Epoch :  454   유일권 목소리 입니다
# Epoch :  455   유일권 목소리 입니다
# Epoch :  456   유일권 목소리 입니다
# Epoch :  457   유일권 목소리 입니다
# Epoch :  458   유일권 목소리 입니다
# Epoch :  459   유일권 목소리 입니다
# Epoch :  460   유일권 목소리 입니다
# Epoch :  461   유일권 목소리 입니다
# Epoch :  462   유일권 목소리 입니다
# Epoch :  463   유일권 목소리 입니다
# Epoch :  464   유일권 목소리 입니다
# Epoch :  465   유일권 목소리 입니다
# Epoch :  466   유일권 목소리 입니다
# Epoch :  467   유일권 목소리 입니다
# Epoch :  468   유일권 목소리 입니다
# Epoch :  469   유일권 목소리 입니다
# Epoch :  470   유일권 목소리 입니다
# Epoch :  471   유일권 목소리 입니다
# Epoch :  472   유일권 목소리 입니다
# Epoch :  473   유일권 목소리 입니다
# Epoch :  474   유일권 목소리 입니다
# Epoch :  475   유일권 목소리 입니다
# Epoch :  476   유일권 목소리 입니다
# Epoch :  477   유일권 목소리 입니다
# Epoch :  478   유일권 목소리 입니다
# Epoch :  479   유일권 목소리 입니다
# Epoch :  480   유일권 목소리 입니다
# Epoch :  481   유일권 목소리 입니다
# Epoch :  482   유일권 목소리 입니다
# Epoch :  483   유일권 목소리 입니다
# Epoch :  484   유일권 목소리 입니다
# Epoch :  485   유일권 목소리 입니다
# Epoch :  486   유일권 목소리 입니다
# Epoch :  487   유일권 목소리 입니다
# Epoch :  488   유일권 목소리 입니다
# Epoch :  489   유일권 목소리 입니다
# Epoch :  490   유일권 목소리 입니다
# Epoch :  491   유일권 목소리 입니다
# Epoch :  492   유일권 목소리 입니다
# Epoch :  493   유일권 목소리 입니다
# Epoch :  494   유일권 목소리 입니다
# Epoch :  495   유일권 목소리 입니다
# Epoch :  496   유일권 목소리 입니다
# Epoch :  497   유일권 목소리 입니다
# Epoch :  498   유일권 목소리 입니다
# Epoch :  499   유일권 목소리 입니다
# Epoch :  500   유일권 목소리 입니다
# Epoch :  501   유일권 목소리 입니다
# Epoch :  502   유일권 목소리 입니다
# Epoch :  503   유일권 목소리 입니다
# Epoch :  504   유일권 목소리 입니다
# Epoch :  505   유일권 목소리 입니다
# Epoch :  506   유일권 목소리 입니다
# Epoch :  507   유일권 목소리 입니다
# Epoch :  508   유일권 목소리 입니다
# Epoch :  509   유일권 목소리 입니다
# Epoch :  510   유일권 목소리 입니다
# Epoch :  511   유일권 목소리 입니다
# Epoch :  512   유일권 목소리 입니다
# Epoch :  513   유일권 목소리 입니다
# Epoch :  514   유일권 목소리 입니다
# Epoch :  515   유일권 목소리 입니다
# Epoch :  516   유일권 목소리 입니다
# Epoch :  517   유일권 목소리 입니다
# Epoch :  518   유일권 목소리 입니다
# Epoch :  519   유일권 목소리 입니다
# Epoch :  520   유일권 목소리 입니다
# Epoch :  521   유일권 목소리 입니다
# Epoch :  522   유일권 목소리 입니다
# Epoch :  523   유일권 목소리 입니다
# Epoch :  524   유일권 목소리 입니다
# Epoch :  525   유일권 목소리 입니다
# Epoch :  526   유일권 목소리 입니다
# Epoch :  527   유일권 목소리 입니다
# Epoch :  528   유일권 목소리 입니다
# Epoch :  529   유일권 목소리 입니다
# Epoch :  530   유일권 목소리 입니다
# Epoch :  531   유일권 목소리 입니다
# Epoch :  532   유일권 목소리 입니다
# Epoch :  533   유일권 목소리 입니다
# Epoch :  534   유일권 목소리 입니다
# Epoch :  535   유일권 목소리 입니다
# Epoch :  536   유일권 목소리 입니다
# Epoch :  537   유일권 목소리 입니다
# Epoch :  538   유일권 목소리 입니다
# Epoch :  539   유일권 목소리 입니다
# Epoch :  540   유일권 목소리 입니다
# Epoch :  541   유일권 목소리 입니다
# Epoch :  542   유일권 목소리 입니다
# Epoch :  543   유일권 목소리 입니다
# Epoch :  544   유일권 목소리 입니다
# Epoch :  545   유일권 목소리 입니다
# Epoch :  546   유일권 목소리 입니다
# Epoch :  547   유일권 목소리 입니다
# Epoch :  548   유일권 목소리 입니다
# Epoch :  549   유일권 목소리 입니다
# Epoch :  550   유일권 목소리 입니다
# Epoch :  551   유일권 목소리 입니다
# Epoch :  552   유일권 목소리 입니다
# Epoch :  553   유일권 목소리 입니다
# Epoch :  554   유일권 목소리 입니다
# Epoch :  555   유일권 목소리 입니다
# Epoch :  556   유일권 목소리 입니다
# Epoch :  557   유일권 목소리 입니다
# Epoch :  558   유일권 목소리 입니다
# Epoch :  559   유일권 목소리 입니다
# Epoch :  560   유일권 목소리 입니다
# Epoch :  561   유일권 목소리 입니다
# Epoch :  562   유일권 목소리 입니다
# Epoch :  563   유일권 목소리 입니다
# Epoch :  564   유일권 목소리 입니다
# Epoch :  565   유일권 목소리 입니다
# Epoch :  566   유일권 목소리 입니다
# Epoch :  567   유일권 목소리 입니다
# Epoch :  568   유일권 목소리 입니다
# Epoch :  569   유일권 목소리 입니다
# Epoch :  570   유일권 목소리 입니다
# Epoch :  571   유일권 목소리 입니다
# Epoch :  572   유일권 목소리 입니다
# Epoch :  573   유일권 목소리 입니다
# Epoch :  574   유일권 목소리 입니다
# Epoch :  575   유일권 목소리 입니다
# Epoch :  576   유일권 목소리 입니다
# Epoch :  577   유일권 목소리 입니다
# Epoch :  578   유일권 목소리 입니다
# Epoch :  579   유일권 목소리 입니다
# Epoch :  580   유일권 목소리 입니다
# Epoch :  581   유일권 목소리 입니다
# Epoch :  582   유일권 목소리 입니다
# Epoch :  583   유일권 목소리 입니다
# Epoch :  584   유일권 목소리 입니다
# Epoch :  585   유일권 목소리 입니다
# Epoch :  586   유일권 목소리 입니다
# Epoch :  587   유일권 목소리 입니다
# Epoch :  588   유일권 목소리 입니다
# Epoch :  589   유일권 목소리 입니다
# Epoch :  590   유일권 목소리 입니다
# Epoch :  591   유일권 목소리 입니다
# Epoch :  592   유일권 목소리 입니다
# Epoch :  593   유일권 목소리 입니다
# Epoch :  594   유일권 목소리 입니다
# Epoch :  595   유일권 목소리 입니다
# Epoch :  596   유일권 목소리 입니다
# Epoch :  597   유일권 목소리 입니다
# Epoch :  598   유일권 목소리 입니다
# Epoch :  599   유일권 목소리 입니다
# Epoch :  600   유일권 목소리 입니다
# Epoch :  601   유일권 목소리 입니다
# Epoch :  602   유일권 목소리 입니다
# Epoch :  603   유일권 목소리 입니다
# Epoch :  604   유일권 목소리 입니다
# Epoch :  605   유일권 목소리 입니다
# Epoch :  606   유일권 목소리 입니다
# Epoch :  607   유일권 목소리 입니다
# Epoch :  608   유일권 목소리 입니다
# Epoch :  609   유일권 목소리 입니다
# Epoch :  610   유일권 목소리 입니다
# Epoch :  611   유일권 목소리 입니다
# Epoch :  612   유일권 목소리 입니다
# Epoch :  613   유일권 목소리 입니다
# Epoch :  614   유일권 목소리 입니다
# Epoch :  615   유일권 목소리 입니다
# Epoch :  616   유일권 목소리 입니다
# Epoch :  617   유일권 목소리 입니다
# Epoch :  618   유일권 목소리 입니다
# Epoch :  619   유일권 목소리 입니다
# Epoch :  620   유일권 목소리 입니다
# Epoch :  621   유일권 목소리 입니다
# Epoch :  622   유일권 목소리 입니다
# Epoch :  623   유일권 목소리 입니다
# Epoch :  624   유일권 목소리 입니다
# Epoch :  625   유일권 목소리 입니다
# Epoch :  626   유일권 목소리 입니다
# Epoch :  627   유일권 목소리 입니다
# Epoch :  628   유일권 목소리 입니다
# Epoch :  629   유일권 목소리 입니다
# Epoch :  630   유일권 목소리 입니다
# Epoch :  631   유일권 목소리 입니다
# Epoch :  632   유일권 목소리 입니다
# Epoch :  633   유일권 목소리 입니다
# Epoch :  634   유일권 목소리 입니다
# Epoch :  635   유일권 목소리 입니다
# Epoch :  636   유일권 목소리 입니다
# Epoch :  637   유일권 목소리 입니다
# Epoch :  638   유일권 목소리 입니다
# Epoch :  639   유일권 목소리 입니다
# Epoch :  640   유일권 목소리 입니다
# Epoch :  641   유일권 목소리 입니다
# Epoch :  642   유일권 목소리 입니다
# Epoch :  643   유일권 목소리 입니다
# Epoch :  644   유일권 목소리 입니다
# Epoch :  645   유일권 목소리 입니다
# Epoch :  646   유일권 목소리 입니다
# Epoch :  647   유일권 목소리 입니다
# Epoch :  648   유일권 목소리 입니다
# Epoch :  649   유일권 목소리 입니다
# Epoch :  650   유일권 목소리 입니다
# Epoch :  651   유일권 목소리 입니다
# Epoch :  652   유일권 목소리 입니다
# Epoch :  653   유일권 목소리 입니다
# Epoch :  654   유일권 목소리 입니다
# Epoch :  655   유일권 목소리 입니다
# Epoch :  656   유일권 목소리 입니다
# Epoch :  657   유일권 목소리 입니다
# Epoch :  658   유일권 목소리 입니다
# Epoch :  659   유일권 목소리 입니다
# Epoch :  660   유일권 목소리 입니다
# Epoch :  661   유일권 목소리 입니다
# Epoch :  662   유일권 목소리 입니다
# Epoch :  663   유일권 목소리 입니다
# Epoch :  664   유일권 목소리 입니다
# Epoch :  665   유일권 목소리 입니다
# Epoch :  666   유일권 목소리 입니다
# Epoch :  667   유일권 목소리 입니다
# Epoch :  668   유일권 목소리 입니다
# Epoch :  669   유일권 목소리 입니다
# Epoch :  670   유일권 목소리 입니다
# Epoch :  671   유일권 목소리 입니다
# Epoch :  672   유일권 목소리 입니다
# Epoch :  673   유일권 목소리 입니다
# Epoch :  674   유일권 목소리 입니다
# Epoch :  675   유일권 목소리 입니다
# Epoch :  676   유일권 목소리 입니다
# Epoch :  677   유일권 목소리 입니다
# Epoch :  678   유일권 목소리 입니다
# Epoch :  679   유일권 목소리 입니다
# Epoch :  680   유일권 목소리 입니다
# Epoch :  681   유일권 목소리 입니다
# Epoch :  682   유일권 목소리 입니다
# Epoch :  683   유일권 목소리 입니다
# Epoch :  684   유일권 목소리 입니다
# Epoch :  685   유일권 목소리 입니다
# Epoch :  686   유일권 목소리 입니다
# Epoch :  687   유일권 목소리 입니다
# Epoch :  688   유일권 목소리 입니다
# Epoch :  689   유일권 목소리 입니다
# Epoch :  690   유일권 목소리 입니다
# Epoch :  691   유일권 목소리 입니다
# Epoch :  692   유일권 목소리 입니다
# Epoch :  693   유일권 목소리 입니다
# Epoch :  694   유일권 목소리 입니다
# Epoch :  695   유일권 목소리 입니다
# Epoch :  696   유일권 목소리 입니다
# Epoch :  697   유일권 목소리 입니다
# Epoch :  698   유일권 목소리 입니다
# Epoch :  699   유일권 목소리 입니다
# Epoch :  700   유일권 목소리 입니다
# Epoch :  701   유일권 목소리 입니다
# Epoch :  702   유일권 목소리 입니다
# Epoch :  703   유일권 목소리 입니다
# Epoch :  704   유일권 목소리 입니다
# Epoch :  705   유일권 목소리 입니다
# Epoch :  706   유일권 목소리 입니다
# Epoch :  707   유일권 목소리 입니다
# Epoch :  708   유일권 목소리 입니다
# Epoch :  709   유일권 목소리 입니다
# Epoch :  710   유일권 목소리 입니다
# Epoch :  711   유일권 목소리 입니다
# Epoch :  712   유일권 목소리 입니다
# Epoch :  713   유일권 목소리 입니다
# Epoch :  714   유일권 목소리 입니다
# Epoch :  715   유일권 목소리 입니다
# Epoch :  716   유일권 목소리 입니다
# Epoch :  717   유일권 목소리 입니다
# Epoch :  718   유일권 목소리 입니다
# Epoch :  719   유일권 목소리 입니다
# Epoch :  720   유일권 목소리 입니다
# Epoch :  721   유일권 목소리 입니다
# Epoch :  722   유일권 목소리 입니다
# Epoch :  723   유일권 목소리 입니다
# Epoch :  724   유일권 목소리 입니다
# Epoch :  725   유일권 목소리 입니다
# Epoch :  726   유일권 목소리 입니다
# Epoch :  727   유일권 목소리 입니다
# Epoch :  728   유일권 목소리 입니다
# Epoch :  729   유일권 목소리 입니다
# Epoch :  730   유일권 목소리 입니다
# Epoch :  731   유일권 목소리 입니다
# Epoch :  732   유일권 목소리 입니다
# Epoch :  733   유일권 목소리 입니다
# Epoch :  734   유일권 목소리 입니다
# Epoch :  735   유일권 목소리 입니다
# Epoch :  736   유일권 목소리 입니다
# Epoch :  737   유일권 목소리 입니다
# Epoch :  738   유일권 목소리 입니다
# Epoch :  739   유일권 목소리 입니다
# Epoch :  740   유일권 목소리 입니다
# Epoch :  741   유일권 목소리 입니다
# Epoch :  742   유일권 목소리 입니다
# Epoch :  743   유일권 목소리 입니다
# Epoch :  744   유일권 목소리 입니다
# Epoch :  745   유일권 목소리 입니다
# Epoch :  746   유일권 목소리 입니다
# Epoch :  747   유일권 목소리 입니다
# Epoch :  748   유일권 목소리 입니다
# Epoch :  749   유일권 목소리 입니다
# Epoch :  750   유일권 목소리 입니다
# Epoch :  751   유일권 목소리 입니다
# Epoch :  752   유일권 목소리 입니다
# Epoch :  753   유일권 목소리 입니다
# Epoch :  754   유일권 목소리 입니다
# Epoch :  755   유일권 목소리 입니다
# Epoch :  756   유일권 목소리 입니다
# Epoch :  757   유일권 목소리 입니다
# Epoch :  758   유일권 목소리 입니다
# Epoch :  759   유일권 목소리 입니다
# Epoch :  760   유일권 목소리 입니다
# Epoch :  761   유일권 목소리 입니다
# Epoch :  762   유일권 목소리 입니다
# Epoch :  763   유일권 목소리 입니다
# Epoch :  764   유일권 목소리 입니다
# Epoch :  765   유일권 목소리 입니다
# Epoch :  766   유일권 목소리 입니다
# Epoch :  767   유일권 목소리 입니다
# Epoch :  768   유일권 목소리 입니다
# Epoch :  769   유일권 목소리 입니다
# Epoch :  770   유일권 목소리 입니다
# Epoch :  771   유일권 목소리 입니다
# Epoch :  772   유일권 목소리 입니다
# Epoch :  773   유일권 목소리 입니다
# Epoch :  774   유일권 목소리 입니다
# Epoch :  775   유일권 목소리 입니다
# Epoch :  776   유일권 목소리 입니다
# Epoch :  777   유일권 목소리 입니다
# Epoch :  778   유일권 목소리 입니다
# Epoch :  779   유일권 목소리 입니다
# Epoch :  780   유일권 목소리 입니다
# Epoch :  781   유일권 목소리 입니다
# Epoch :  782   유일권 목소리 입니다
# Epoch :  783   유일권 목소리 입니다
# Epoch :  784   유일권 목소리 입니다
# Epoch :  785   유일권 목소리 입니다
# Epoch :  786   유일권 목소리 입니다
# Epoch :  787   유일권 목소리 입니다
# Epoch :  788   유일권 목소리 입니다
# Epoch :  789   유일권 목소리 입니다
# Epoch :  790   경재원 목소리 입니다
# Epoch :  791   유일권 목소리 입니다
# Epoch :  792   유일권 목소리 입니다
# Epoch :  793   유일권 목소리 입니다
# Epoch :  794   유일권 목소리 입니다
# Epoch :  795   유일권 목소리 입니다
# Epoch :  796   유일권 목소리 입니다
# Epoch :  797   유일권 목소리 입니다
# Epoch :  798   유일권 목소리 입니다
# Epoch :  799   유일권 목소리 입니다
# Epoch :  800   유일권 목소리 입니다
# Epoch :  801   유일권 목소리 입니다
# Epoch :  802   유일권 목소리 입니다
# Epoch :  803   유일권 목소리 입니다
# Epoch :  804   유일권 목소리 입니다
# Epoch :  805   유일권 목소리 입니다
# Epoch :  806   유일권 목소리 입니다
# Epoch :  807   유일권 목소리 입니다
# Epoch :  808   유일권 목소리 입니다
# Epoch :  809   유일권 목소리 입니다
# Epoch :  810   유일권 목소리 입니다
# Epoch :  811   유일권 목소리 입니다
# Epoch :  812   유일권 목소리 입니다
# Epoch :  813   유일권 목소리 입니다
# Epoch :  814   유일권 목소리 입니다
# Epoch :  815   유일권 목소리 입니다
# Epoch :  816   유일권 목소리 입니다
# Epoch :  817   유일권 목소리 입니다
# Epoch :  818   유일권 목소리 입니다
# Epoch :  819   유일권 목소리 입니다
# Epoch :  820   유일권 목소리 입니다
# Epoch :  821   유일권 목소리 입니다
# Epoch :  822   유일권 목소리 입니다
# Epoch :  823   유일권 목소리 입니다
# Epoch :  824   유일권 목소리 입니다
# Epoch :  825   유일권 목소리 입니다
# Epoch :  826   유일권 목소리 입니다
# Epoch :  827   유일권 목소리 입니다
# Epoch :  828   유일권 목소리 입니다
# Epoch :  829   유일권 목소리 입니다
# Epoch :  830   유일권 목소리 입니다
# Epoch :  831   유일권 목소리 입니다
# Epoch :  832   유일권 목소리 입니다
# Epoch :  833   유일권 목소리 입니다
# Epoch :  834   유일권 목소리 입니다
# Epoch :  835   유일권 목소리 입니다
# Epoch :  836   유일권 목소리 입니다
# Epoch :  837   유일권 목소리 입니다
# Epoch :  838   유일권 목소리 입니다
# Epoch :  839   유일권 목소리 입니다
# Epoch :  840   유일권 목소리 입니다
# Epoch :  841   유일권 목소리 입니다
# Epoch :  842   유일권 목소리 입니다
# Epoch :  843   유일권 목소리 입니다
# Epoch :  844   유일권 목소리 입니다
# Epoch :  845   유일권 목소리 입니다
# Epoch :  846   유일권 목소리 입니다
# Epoch :  847   유일권 목소리 입니다
# Epoch :  848   유일권 목소리 입니다
# Epoch :  849   유일권 목소리 입니다
# Epoch :  850   유일권 목소리 입니다
# Epoch :  851   유일권 목소리 입니다
# Epoch :  852   유일권 목소리 입니다
# Epoch :  853   유일권 목소리 입니다
# Epoch :  854   유일권 목소리 입니다
# Epoch :  855   유일권 목소리 입니다
# Epoch :  856   유일권 목소리 입니다
# Epoch :  857   유일권 목소리 입니다
# Epoch :  858   유일권 목소리 입니다
# Epoch :  859   유일권 목소리 입니다
# Epoch :  860   유일권 목소리 입니다
# Epoch :  861   유일권 목소리 입니다
# Epoch :  862   유일권 목소리 입니다
# Epoch :  863   유일권 목소리 입니다
# Epoch :  864   유일권 목소리 입니다
# Epoch :  865   유일권 목소리 입니다
# Epoch :  866   유일권 목소리 입니다
# Epoch :  867   유일권 목소리 입니다
# Epoch :  868   유일권 목소리 입니다
# Epoch :  869   유일권 목소리 입니다
# Epoch :  870   유일권 목소리 입니다
# Epoch :  871   유일권 목소리 입니다
# Epoch :  872   유일권 목소리 입니다
# Epoch :  873   유일권 목소리 입니다
# Epoch :  874   유일권 목소리 입니다
# Epoch :  875   유일권 목소리 입니다
# Epoch :  876   유일권 목소리 입니다
# Epoch :  877   유일권 목소리 입니다
# Epoch :  878   유일권 목소리 입니다
# Epoch :  879   유일권 목소리 입니다
# Epoch :  880   유일권 목소리 입니다
# Epoch :  881   유일권 목소리 입니다
# Epoch :  882   유일권 목소리 입니다
# Epoch :  883   유일권 목소리 입니다
# Epoch :  884   유일권 목소리 입니다
# Epoch :  885   유일권 목소리 입니다
# Epoch :  886   유일권 목소리 입니다
# Epoch :  887   유일권 목소리 입니다
# Epoch :  888   유일권 목소리 입니다
# Epoch :  889   유일권 목소리 입니다
# Epoch :  890   유일권 목소리 입니다
# Epoch :  891   유일권 목소리 입니다
# Epoch :  892   유일권 목소리 입니다
# Epoch :  893   유일권 목소리 입니다
# Epoch :  894   유일권 목소리 입니다
# Epoch :  895   유일권 목소리 입니다
# Epoch :  896   유일권 목소리 입니다
# Epoch :  897   유일권 목소리 입니다
# Epoch :  898   유일권 목소리 입니다
# Epoch :  899   유일권 목소리 입니다
# Epoch :  900   유일권 목소리 입니다
# Epoch :  901   유일권 목소리 입니다
# Epoch :  902   유일권 목소리 입니다
# Epoch :  903   유일권 목소리 입니다
# Epoch :  904   유일권 목소리 입니다
# Epoch :  905   유일권 목소리 입니다
# Epoch :  906   유일권 목소리 입니다
# Epoch :  907   유일권 목소리 입니다
# Epoch :  908   유일권 목소리 입니다
# Epoch :  909   유일권 목소리 입니다
# Epoch :  910   유일권 목소리 입니다
# Epoch :  911   유일권 목소리 입니다
# Epoch :  912   유일권 목소리 입니다
# Epoch :  913   유일권 목소리 입니다
# Epoch :  914   유일권 목소리 입니다
# Epoch :  915   유일권 목소리 입니다
# Epoch :  916   유일권 목소리 입니다
# Epoch :  917   유일권 목소리 입니다
# Epoch :  918   유일권 목소리 입니다
# Epoch :  919   유일권 목소리 입니다
# Epoch :  920   유일권 목소리 입니다
# Epoch :  921   유일권 목소리 입니다
# Epoch :  922   유일권 목소리 입니다
# Epoch :  923   유일권 목소리 입니다
# Epoch :  924   유일권 목소리 입니다
# Epoch :  925   유일권 목소리 입니다
# Epoch :  926   유일권 목소리 입니다
# Epoch :  927   유일권 목소리 입니다
# Epoch :  928   유일권 목소리 입니다
# Epoch :  929   유일권 목소리 입니다
# Epoch :  930   유일권 목소리 입니다
# Epoch :  931   유일권 목소리 입니다
# Epoch :  932   유일권 목소리 입니다
# Epoch :  933   유일권 목소리 입니다
# Epoch :  934   유일권 목소리 입니다
# Epoch :  935   유일권 목소리 입니다
# Epoch :  936   유일권 목소리 입니다
# Epoch :  937   유일권 목소리 입니다
# Epoch :  938   유일권 목소리 입니다
# Epoch :  939   유일권 목소리 입니다
# Epoch :  940   유일권 목소리 입니다
# Epoch :  941   유일권 목소리 입니다
# Epoch :  942   유일권 목소리 입니다
# Epoch :  943   유일권 목소리 입니다
# Epoch :  944   유일권 목소리 입니다
# Epoch :  945   유일권 목소리 입니다
# Epoch :  946   유일권 목소리 입니다
# Epoch :  947   유일권 목소리 입니다
# Epoch :  948   유일권 목소리 입니다
# Epoch :  949   유일권 목소리 입니다
# Epoch :  950   유일권 목소리 입니다
# Epoch :  951   유일권 목소리 입니다
# Epoch :  952   유일권 목소리 입니다
# Epoch :  953   유일권 목소리 입니다
# Epoch :  954   유일권 목소리 입니다
# Epoch :  955   유일권 목소리 입니다
# Epoch :  956   유일권 목소리 입니다
# Epoch :  957   유일권 목소리 입니다
# Epoch :  958   유일권 목소리 입니다
# Epoch :  959   유일권 목소리 입니다
# Epoch :  960   유일권 목소리 입니다
# Epoch :  961   유일권 목소리 입니다
# Epoch :  962   유일권 목소리 입니다
# Epoch :  963   유일권 목소리 입니다
# Epoch :  964   유일권 목소리 입니다
# Epoch :  965   유일권 목소리 입니다
# Epoch :  966   유일권 목소리 입니다
# Epoch :  967   유일권 목소리 입니다
# Epoch :  968   유일권 목소리 입니다
# Epoch :  969   유일권 목소리 입니다
# Epoch :  970   유일권 목소리 입니다
# Epoch :  971   유일권 목소리 입니다
# Epoch :  972   유일권 목소리 입니다
# Epoch :  973   유일권 목소리 입니다
# Epoch :  974   유일권 목소리 입니다
# Epoch :  975   유일권 목소리 입니다
# Epoch :  976   유일권 목소리 입니다
# Epoch :  977   유일권 목소리 입니다
# Epoch :  978   유일권 목소리 입니다
# Epoch :  979   유일권 목소리 입니다
# Epoch :  980   유일권 목소리 입니다
# Epoch :  981   유일권 목소리 입니다
# Epoch :  982   유일권 목소리 입니다
# Epoch :  983   유일권 목소리 입니다
# Epoch :  984   유일권 목소리 입니다
# Epoch :  985   유일권 목소리 입니다
# Epoch :  986   유일권 목소리 입니다
# Epoch :  987   유일권 목소리 입니다
# Epoch :  988   유일권 목소리 입니다
# Epoch :  989   유일권 목소리 입니다
# Epoch :  990   유일권 목소리 입니다
# Epoch :  991   유일권 목소리 입니다
# Epoch :  992   유일권 목소리 입니다
# Epoch :  993   유일권 목소리 입니다
# Epoch :  994   유일권 목소리 입니다
# Epoch :  995   유일권 목소리 입니다
# Epoch :  996   유일권 목소리 입니다
# Epoch :  997   유일권 목소리 입니다
# Epoch :  998   유일권 목소리 입니다
# Epoch :  999   유일권 목소리 입니다
# [0, 996, 4]

# %%
generator.save('GRU_v2.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
